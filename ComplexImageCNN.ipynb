# %%
# !pip install pytorch-complex-tensor
# !pip install pytorch-complex
from pytorch_complex_tensor import ComplexTensor
import torchcomplex
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms, models
from torchvision.utils import make_grid
import os
import random
import numpy as np
import pandas as pd
import pickle
import time
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, jaccard_similarity_score
from google.colab import drive
# !pip install complexPyTorch
from complexPyTorch.complexLayers import ComplexBatchNorm2d, ComplexConv2d, ComplexLinear
from complexPyTorch.complexFunctions import complex_relu, complex_max_pool2d
# Out:
# Collecting pytorch-complex-tensor
#   Downloading https://files.pythonhosted.org/packages/0e/98/6e5718dd0c7d7b648c560624aea9a81b98b0442e03a7ff4c81430b0c8082/pytorch-complex-tensor-0.0.134.tar.gz
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pytorch-complex-tensor) (1.19.5)
# Requirement already satisfied: torch>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-complex-tensor) (1.9.0+cu102)
# Requirement already satisfied: torchvision>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-complex-tensor) (0.10.0+cu102)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.0->pytorch-complex-tensor) (3.7.4.3)
# Requirement already satisfied: pillow>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.2.1->pytorch-complex-tensor) (7.1.2)
# Building wheels for collected packages: pytorch-complex-tensor
#   Building wheel for pytorch-complex-tensor (setup.py) ... done
#   Created wheel for pytorch-complex-tensor: filename=pytorch_complex_tensor-0.0.134-cp37-none-any.whl size=8208 sha256=1ebcd9e0857e664fd33303b0614a9b8a205784b33b82ac26627521c2b46cd79d
#   Stored in directory: /root/.cache/pip/wheels/12/9c/1c/35f0a149f864e1b4d5f0711bf76745aebef1f306fc8ab9ec40
# Successfully built pytorch-complex-tensor
# Installing collected packages: pytorch-complex-tensor
# Successfully installed pytorch-complex-tensor-0.0.134
# Collecting pytorch-complex
#   Downloading https://files.pythonhosted.org/packages/16/78/06b3d8c7937e772773ca0bccbb3880fa71dd574b7f20d44ec01d07fb6f80/pytorch_complex-0.0.8-py3-none-any.whl (42kB)
#      |████████████████████████████████| 51kB 2.3MB/s
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.7/dist-packages (from pytorch-complex) (1.9.0+cu102)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.7->pytorch-complex) (3.7.4.3)
# Installing collected packages: pytorch-complex
# Successfully installed pytorch-complex-0.0.8
# Collecting complexPyTorch
#   Downloading https://files.pythonhosted.org/packages/64/eb/182b68dc251a66f9aa1141c95f02c7b6e4876cb5eb396fa7cb1ae9b6d1b9/complexPyTorch-0.3-py3-none-any.whl
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from complexPyTorch) (1.9.0+cu102)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->complexPyTorch) (3.7.4.3)
# Installing collected packages: complexPyTorch
# Successfully installed complexPyTorch-0.3

# %%
# !nvidia-smi
# Out:
# Thu Jun 24 18:59:52 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
training_data = pickle.load(open('/content/drive/My Drive/trainingData.pickle', 'rb'))

# %%
Xt = []
yt = []
features = None
labels = None
label = []

# %%
for features,labels in training_data:
  Xt.append(features)
  yt.append(labels)

# %%
a = np.array(Xt)
b = np.array(yt)
type(a)
# Out:
# numpy.ndarray

# %%
X_train, X_test, y_train, y_test = train_test_split(a, b, test_size=0.25, shuffle=True)  # 70% training, 25% testing

# %%
print("Xtrain data shape",X_train.shape)
print("YTrain data shape",y_train.shape)
# Out:
# Xtrain data shape (2298, 512, 512, 3)
# YTrain data shape (2298,)

# %%
# visualizing images
i = 0
plt.figure(figsize=(10,10))
plt.subplot(221), plt.imshow(X_train[i], cmap='gray')
plt.subplot(222), plt.imshow(X_train[i+30], cmap='gray')
plt.subplot(223), plt.imshow(X_train[i+50], cmap='gray')
plt.subplot(224), plt.imshow(X_train[i+100], cmap='gray')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f70f849ba10>,
#  <matplotlib.image.AxesImage at 0x7f70f8455c50>)

# %%
X_train[1].shape
# Out:
# (512, 512, 3)

# %%
class ComplexImage(Dataset):
  def __init__(self, images, labels):
    # images
    self.X = images
    # labels
    self.y = labels
    #converts numpy array to tensor
    self.transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (1.0,))])
  def __len__(self):
    # return length of image samples
    return len(self.X)

  def __getitem__(self, idx):
    # perform transformations on one instance of X
    # numpy array as a tensor
    d = self.transform(self.X[idx])
    data = torch.fft.ifftn(d)
    data = torch.fft.ifftn(d)
    
    # store the transformed images in a list
    new_batch = [data]

    # one-hot encode the labels
    labels = torch.zeros(4, dtype=torch.float32)
    labels[int(self.y[idx])] = 1.0
    #labels = self.y[idx]
    new_labels = [labels]
    # 8 augmented images and corresponding labels per sample will be returned
    return (torch.stack(new_labels), torch.stack(new_batch))

# %%
Xt = None
yt = None
features = None
labels = None
label = None
training_data = None
a = None
b = None

# %%
train_set = ComplexImage(X_train, y_train)
test_set = ComplexImage(X_test, y_test)

# %%
print(f"Number of training samples: {len(X_train)}")
print(f"Number of testing samples: {len(X_test)}")
# Out:
# Number of training samples: 2298
# Number of testing samples: 766

# %%
#torch.max(train_set[0][1])
(train_set[0][1].type(torch.float64).max())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  /pytorch/aten/src/ATen/native/Copy.cpp:240.)
# tensor(0.0135, dtype=torch.float64)

# %%
train_gen = DataLoader(train_set, batch_size=4, shuffle=True, pin_memory=True, num_workers=8)
test_gen = DataLoader(test_set, batch_size=4, shuffle=True, pin_memory=True, num_workers=8)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
class ComplexCnn(nn.Module):
    
    def __init__(self):
        super(ComplexCnn, self).__init__()
        self.conv1 = ComplexConv2d(3,64,5)
        self.bn  = ComplexBatchNorm2d(64)
        self.conv2 = ComplexConv2d(64, 16, 5)
        self.fc1 = ComplexLinear(16*125*125, 1000)
        self.fc2 = ComplexLinear(1000, 100)
             
    def forward(self,x):
        x = self.conv1(x)
        x = complex_relu(x)
        x = complex_max_pool2d(x, 2, 2)
        x = self.bn(x)
        x = self.conv2(x)
        x = complex_relu(x)
        x = complex_max_pool2d(x, 2, 2)
        x = x.view(-1,16*125*125)
        x = self.fc1(x)
        x = complex_relu(x)
        x = self.fc2(x)
        x = x.abs()
        x =  F.log_softmax(x, dim=1)
        return x

# %%
device = device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# defining the model
complexdmodel = ComplexCnn().to(device)  
print(complexdmodel)
# Out:
# ComplexCnn(
#   (conv1): ComplexConv2d(
#     (conv_r): Conv2d(3, 64, kernel_size=(5, 5), stride=(1, 1))
#     (conv_i): Conv2d(3, 64, kernel_size=(5, 5), stride=(1, 1))
#   )
#   (bn): ComplexBatchNorm2d()
#   (conv2): ComplexConv2d(
#     (conv_r): Conv2d(64, 16, kernel_size=(5, 5), stride=(1, 1))
#     (conv_i): Conv2d(64, 16, kernel_size=(5, 5), stride=(1, 1))
#   )
#   (fc1): ComplexLinear(
#     (fc_r): Linear(in_features=250000, out_features=1000, bias=True)
#     (fc_i): Linear(in_features=250000, out_features=1000, bias=True)
#   )
#   (fc2): ComplexLinear(
#     (fc_r): Linear(in_features=1000, out_features=100, bias=True)
#     (fc_i): Linear(in_features=1000, out_features=100, bias=True)
#   )
# )

# %%
# loss function
# if GPU is available set loss function to use GPU
criterion = nn.CrossEntropyLoss().to(device)

# optimizer
optimizer = torch.optim.SGD(complexdmodel.parameters(), lr=3e-4, momentum=0.9)

# number of training iterations
epochs = 30

# empty lists to store losses and accuracies
train_losses = []
test_losses = []
train_correct = []
test_correct = []

# %%
def save_checkpoint(state, is_best, filename='/content/drive/My Drive/bt_complexCnn_ckpt_v2.pth.tar'):
    torch.save(state, filename)

# %%
# set training start time
start_time = time.time()

# set best_prec loss value as 2 for checkpoint threshold
best_prec1 = 2

# empty batch variables
b = None
train_b = None
test_b = None

# start training
for i in range(epochs):
    # empty training correct and test correct counter as 0 during every iteration
    trn_corr = 0
    tst_corr = 0
    
    # set epoch's starting time
    e_start = time.time()
    
    # train in batches
    for b, (y, X) in enumerate(train_set):
        # set label as cuda if device is cuda
        X, y = X.to(device), y.to(device) # real image tensors is converted into complex image tensors
        # forward pass image sample
        y_pred = complexdmodel(X.view(-1, 3, 512, 512))
        # calculate loss
        loss = criterion(y_pred.float(), torch.argmax(y.view(1,4), dim=1).long())

        # get argmax of predicted tensor, which is our label
        predicted = torch.argmax(y_pred, dim=1).data
        # if predicted label is correct as true label, calculate the sum for samples
        batch_corr = (predicted == torch.argmax(y.view(1, 4), dim=1)).sum()
        # increment train correct with correcly predicted labels per batch
        trn_corr += batch_corr
        
        # set optimizer gradients to zero
        optimizer.zero_grad()
        # back propagate with loss
        loss.backward()
        # perform optimizer step
        optimizer.step()

    # set epoch's end time
    e_end = time.time()
    # print training metrics
    print(f'Epoch {(i+1)} Batch {(b+1)*1}\nAccuracy: {trn_corr.item()*100/(len(train_set)):2.2f} %  Loss: {loss.item():2.4f}  Duration: {((e_end-e_start)/60):.2f} minutes') # 4 images per batch * 8 augmentations per image * batch length

    # some metrics storage for visualization
    train_b = b
    train_losses.append(loss)
    train_correct.append(trn_corr)

    X, y = None, None

    # validate using validation generator
    # do not perform any gradient updates while validation
    with torch.no_grad():
        for b, (y, X) in enumerate(test_set):
            # set label as cuda if device is cuda
            X, y = X.to(device), y.to(device)
            #print(y.shape)
            # forward pass image
            y_val = complexdmodel(X.view(-1, 3, 512, 512))

            # get argmax of predicted tensor, which is our label
            predicted = torch.argmax(y_val, dim=1).data

            # increment test correct with correcly predicted labels per batch
            tst_corr += (predicted == torch.argmax(y.view(1, 4), dim=1)).sum()

    # get loss of validation set
    loss = criterion(y_val.float(), torch.argmax(y.view(1, 4), dim=1).long())
    # print validation metrics
    print(f'Validation Accuracy {tst_corr.item()*100/(len(test_set)):2.2f} Validation Loss: {loss.item():2.4f}\n')

    # if current validation loss is less than previous iteration's validatin loss create and save a checkpoint
    is_best = loss < best_prec1
    best_prec1 = min(loss, best_prec1)
    save_checkpoint({
            'epoch': i + 1,
            'state_dict': complexdmodel.state_dict(),
            'best_prec1': best_prec1,
        }, is_best)

    # some metrics storage for visualization
    test_b  = b
    test_losses.append(loss)
    test_correct.append(tst_corr)

# set total training's end time
end_time = time.time() - start_time    

# print training summary
print("\nTraining Duration {:.2f} minutes".format(end_time/60))
print("GPU memory used : {} kb".format(torch.cuda.memory_allocated()))
print("GPU memory cached : {} kb".format(torch.cuda.memory_cached()))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:693: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch._C._nn.max_pool2d_with_indices(input, kernel_size, stride, padding, dilation, ceil_mode)
# Epoch 1 Batch 2298
# Accuracy: 55.92 %  Loss: 0.2119  Duration: 5.94 minutes
# Validation Accuracy 70.76 Validation Loss: 0.0393
#
# Epoch 2 Batch 2298
# Accuracy: 70.23 %  Loss: 0.0658  Duration: 5.94 minutes
# Validation Accuracy 75.33 Validation Loss: 0.0661
#
# Epoch 3 Batch 2298
# Accuracy: 75.24 %  Loss: 0.0363  Duration: 5.94 minutes
# Validation Accuracy 77.02 Validation Loss: 0.1895
#
# Epoch 4 Batch 2298
# Accuracy: 79.68 %  Loss: 0.0165  Duration: 5.94 minutes
# Validation Accuracy 79.50 Validation Loss: 0.0420
#
# Epoch 5 Batch 2298
# Accuracy: 83.81 %  Loss: 0.0016  Duration: 5.94 minutes
# Validation Accuracy 82.64 Validation Loss: 0.0285
#
# Epoch 6 Batch 2298
# Accuracy: 87.64 %  Loss: 0.0010  Duration: 5.94 minutes
# Validation Accuracy 84.99 Validation Loss: 0.0567
#
# Epoch 7 Batch 2298
# Accuracy: 91.51 %  Loss: 0.0012  Duration: 5.94 minutes
# Validation Accuracy 87.99 Validation Loss: 0.0083
#
# Epoch 8 Batch 2298
# Accuracy: 94.08 %  Loss: 0.0123  Duration: 5.94 minutes
# Validation Accuracy 86.81 Validation Loss: 0.0002
#
# Epoch 9 Batch 2298
# Accuracy: 95.17 %  Loss: 0.0002  Duration: 5.94 minutes
# Validation Accuracy 83.94 Validation Loss: 0.3718
#
# Epoch 10 Batch 2298
# Accuracy: 96.48 %  Loss: 0.0000  Duration: 5.94 minutes
# Validation Accuracy 87.08 Validation Loss: 0.0041
#
# Epoch 11 Batch 2298
# Accuracy: 97.04 %  Loss: 0.0012  Duration: 5.94 minutes
# Validation Accuracy 86.68 Validation Loss: 0.0000
#
# Epoch 12 Batch 2298
# Accuracy: 97.04 %  Loss: 0.0000  Duration: 5.94 minutes
# Validation Accuracy 89.43 Validation Loss: 0.0004
#
# Epoch 13 Batch 2298
# Accuracy: 97.04 %  Loss: 0.0000  Duration: 5.94 minutes
# Validation Accuracy 88.25 Validation Loss: 0.0094
#
# Epoch 14 Batch 2298
# Accuracy: 98.04 %  Loss: 0.0000  Duration: 5.94 minutes
# Validation Accuracy 86.81 Validation Loss: 0.0061
#
# Epoch 15 Batch 2298
# Accuracy: 98.56 %  Loss: 0.0000  Duration: 5.94 minutes
# Validation Accuracy 88.77 Validation Loss: 0.0001
#
# Epoch 16 Batch 2298
# Accuracy: 98.65 %  Loss: 0.0855  Duration: 5.94 minutes
# Validation Accuracy 86.29 Validation Loss: 0.0000
#
# Epoch 17 Batch 2298
# Accuracy: 98.61 %  Loss: 0.0000  Duration: 5.94 minutes
# Validation Accuracy 88.77 Validation Loss: 0.0003
#
# Epoch 18 Batch 2298
# Accuracy: 98.17 %  Loss: 0.0000  Duration: 5.94 minutes
# Validation Accuracy 89.82 Validation Loss: 0.0005
#
# Epoch 19 Batch 2298
# Accuracy: 98.26 %  Loss: 0.0000  Duration: 5.94 minutes
# Validation Accuracy 89.16 Validation Loss: 0.0010
#
# Epoch 20 Batch 2298
# Accuracy: 98.65 %  Loss: 0.0121  Duration: 5.94 minutes
# Validation Accuracy 85.25 Validation Loss: 0.0001
#
# Epoch 21 Batch 2298
# Accuracy: 98.65 %  Loss: 0.0001  Duration: 5.94 minutes
# Validation Accuracy 91.12 Validation Loss: 0.0000
#
# Epoch 22 Batch 2298
# Accuracy: 99.61 %  Loss: 0.0000  Duration: 5.94 minutes
# Validation Accuracy 90.47 Validation Loss: 0.0001
#
# Epoch 23 Batch 2298
# Accuracy: 99.78 %  Loss: 0.0006  Duration: 5.94 minutes
# Validation Accuracy 90.99 Validation Loss: 0.0000
#
# Epoch 24 Batch 2298
# Accuracy: 100.00 %  Loss: 0.0003  Duration: 5.94 minutes
# Validation Accuracy 90.99 Validation Loss: 0.0000
#
# Epoch 25 Batch 2298
# Accuracy: 100.00 %  Loss: 0.0000  Duration: 5.94 minutes
# Validation Accuracy 91.78 Validation Loss: 0.0001
#
# Epoch 26 Batch 2298
# Accuracy: 100.00 %  Loss: 0.0000  Duration: 5.94 minutes
# Validation Accuracy 91.51 Validation Loss: 0.0001
#
# Epoch 27 Batch 2298
# Accuracy: 100.00 %  Loss: 0.0000  Duration: 5.94 minutes
# Validation Accuracy 92.04 Validation Loss: 0.0001
#
# Epoch 28 Batch 2298
# Accuracy: 100.00 %  Loss: 0.0000  Duration: 5.94 minutes
# Validation Accuracy 91.78 Validation Loss: 0.0001
#
# Epoch 29 Batch 2298
# Accuracy: 100.00 %  Loss: 0.0000  Duration: 5.94 minutes
# Validation Accuracy 91.64 Validation Loss: 0.0001
#
# Epoch 30 Batch 2298
# Accuracy: 100.00 %  Loss: 0.0000  Duration: 5.94 minutes
# Validation Accuracy 91.51 Validation Loss: 0.0001
#
#
# Training Duration 193.87 minutes
# GPU memory used : 6011578880 kb
# GPU memory cached : 11773411328 kb
# /usr/local/lib/python3.7/dist-packages/torch/cuda/memory.py:375: FutureWarning: torch.cuda.memory_cached has been renamed to torch.cuda.memory_reserved
#   FutureWarning)

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(test_losses, label='Validation loss')
plt.title('Loss Metrics')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %%
plt.plot([t/171 for t in train_correct], label='Training accuracy')
plt.plot([t/36 for t in test_correct], label='Validation accuracy')
plt.title('Accuracy Metrics')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend()
plt.show()
